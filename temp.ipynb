# %%
def calc_stock_return(buy_price, current_price, shares=1):
    """
    计算股票盈亏
    buy_price: 买入净值
    current_price: 当前净值
    shares: 份额（默认1)
    """

    cost = buy_price * shares
    value = current_price * shares
    profit = value - cost
    rate = profit / cost * 100

    return {
        "cost": cost,
        "value": value,
        "profit": profit,
        "rate": rate
    }
 
# 示例
ret = calc_stock_return(1.2883, 1.2683, 1540.81)
print(f"成本: {ret['cost']:.2f}")
print(f"当前市值: {ret['value']:.2f}")
print(f"盈亏额: {ret['profit']:.2f}")
print(f"盈亏率: {ret['rate']:.2f}%")
# Out:
# 成本: 1985.03
# 当前市值: 1954.21
# 盈亏额: -30.82
# 盈亏率: -1.55%
